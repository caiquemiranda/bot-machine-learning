# %% [markdown]
# [ ] - Download dados
#
# [ ] - Engenharia de atributos
#
# [ ] - Análise e visualização de dados
#
# [ ] - Contrução de modelo
#
# [ ] - Avaliação de modelo
#
# [ ] - Deploy

# %% [markdown]
# #### Donwload de dados

# %%
import pandas_ta as ta
import yfinance as yf
import pandas as pd

# %%
# Y-m-d
start = '2013-01-01'
end = '2023-09-01'

# %%
vale = yf.download('VALE', 
                   start=start, 
                   end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
vale
# Out:
#              Open       High        Low      Close  Adj Close    Volume
# Date
# 2013-01-02  21.76  21.879999  21.379999  21.490000  12.106179  23912400
# 2013-01-03  21.25  21.510000  21.080000  21.250000  11.970977  18302200
# 2013-01-04  20.91  21.110001  20.650000  21.070000  11.869576  18256800
# 2013-01-07  20.93  20.969999  20.490000  20.680000  11.649876  15003800
# 2013-01-08  20.52  20.580000  20.309999  20.370001  11.475239  12462900
# ...           ...        ...        ...        ...        ...       ...
# 2023-08-25  12.77  12.830000  12.650000  12.740000  12.740000  13184800
# 2023-08-28  12.81  12.950000  12.760000  12.920000  12.920000   9681400
# 2023-08-29  12.99  13.380000  12.930000  13.330000  13.330000  21719400
# 2023-08-30  13.43  13.460000  13.250000  13.330000  13.330000  10979000
# 2023-08-31  13.36  13.420000  13.150000  13.170000  13.170000  15771800
#
# [2685 rows x 6 columns]

# %% [markdown]
# #### Engenharia de atributos

# %% [markdown]
# - [ ] Médias
# - [ ] Distância das Médias
# - [ ] OBV
# - [ ] Média OBV
# - [ ] RSI

# %% [markdown]
# ##### Médias
#
# - mme 7
# - mme 9
# - mme 21
# - mme 50
# - mme 66

# %%
vale['sma7'] = ta.sma(vale['Adj Close'], length=7)
vale['sma9'] = ta.sma(vale['Adj Close'], length=9)
vale['sma21'] = ta.sma(vale['Adj Close'], length=21)
vale['sma50'] = ta.sma(vale['Adj Close'], length=50)
vale['sma66'] = ta.sma(vale['Adj Close'], length=66)

# %%
vale.dropna(inplace=True)
vale.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2013-04-08  17.430000  17.469999  17.100000  17.400000   9.802118  15892600
# 2013-04-09  17.760000  18.410000  17.709999  18.250000  10.280956  27034000
# 2013-04-10  18.450001  18.549999  17.600000  17.770000  10.010556  38261600
# 2013-04-11  17.680000  17.719999  17.129999  17.360001   9.779586  24228300
# 2013-04-12  17.240000  18.170000  16.850000  17.469999   9.841553  33716600
#
#                 sma7      sma9     sma21      sma50      sma66
# Date
# 2013-04-08  9.605754  9.631239  9.805069  10.411089  10.674869
# 2013-04-09  9.683012  9.702595  9.794875  10.396443  10.647214
# 2013-04-10  9.757051  9.725755  9.772879  10.378641  10.617511
# 2013-04-11  9.820628  9.730136  9.739346  10.352840  10.585844
# 2013-04-12  9.862476  9.768944  9.730494  10.330306  10.558446

# %%
vale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2620 entries, 2013-04-08 to 2023-08-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2620 non-null   float64
#  1   High       2620 non-null   float64
#  2   Low        2620 non-null   float64
#  3   Close      2620 non-null   float64
#  4   Adj Close  2620 non-null   float64
#  5   Volume     2620 non-null   int64
#  6   sma7       2620 non-null   float64
#  7   sma9       2620 non-null   float64
#  8   sma21      2620 non-null   float64
#  9   sma50      2620 non-null   float64
#  10  sma66      2620 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 245.6 KB

# %% [markdown]
# ##### Distância médias

# %%
vale['dist7'] = vale['Adj Close']-vale['sma7']
vale['dist9'] = vale['Adj Close']-vale['sma9']
vale['dist21'] = vale['Adj Close']-vale['sma21']
vale['dist50'] = vale['Adj Close']-vale['sma50']
vale['dist66'] = vale['Adj Close']-vale['sma66']

# %%
vale.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2013-04-08  17.430000  17.469999  17.100000  17.400000   9.802118  15892600
# 2013-04-09  17.760000  18.410000  17.709999  18.250000  10.280956  27034000
# 2013-04-10  18.450001  18.549999  17.600000  17.770000  10.010556  38261600
# 2013-04-11  17.680000  17.719999  17.129999  17.360001   9.779586  24228300
# 2013-04-12  17.240000  18.170000  16.850000  17.469999   9.841553  33716600
#
#                 sma7      sma9     sma21      sma50      sma66     dist7  \
# Date
# 2013-04-08  9.605754  9.631239  9.805069  10.411089  10.674869  0.196364
# 2013-04-09  9.683012  9.702595  9.794875  10.396443  10.647214  0.597944
# 2013-04-10  9.757051  9.725755  9.772879  10.378641  10.617511  0.253505
# 2013-04-11  9.820628  9.730136  9.739346  10.352840  10.585844 -0.041042
# 2013-04-12  9.862476  9.768944  9.730494  10.330306  10.558446 -0.020924
#
#                dist9    dist21    dist50    dist66
# ...

# %%
vale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2620 entries, 2013-04-08 to 2023-08-31
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2620 non-null   float64
#  1   High       2620 non-null   float64
#  2   Low        2620 non-null   float64
#  3   Close      2620 non-null   float64
#  4   Adj Close  2620 non-null   float64
#  5   Volume     2620 non-null   int64
#  6   sma7       2620 non-null   float64
#  7   sma9       2620 non-null   float64
#  8   sma21      2620 non-null   float64
#  9   sma50      2620 non-null   float64
#  10  sma66      2620 non-null   float64
#  11  dist7      2620 non-null   float64
#  12  dist9      2620 non-null   float64
#  13  dist21     2620 non-null   float64
#  14  dist50     2620 non-null   float64
#  15  dist66     2620 non-null   float64
# dtypes: float64(15), int64(1)
# memory usage: 348.0 KB

# %% [markdown]
# ##### OBV

# %%
# calculo OBV (on balance volume)
OBV = []
OBV.append(0)
for i in range(1, len(vale['Adj Close'])):
    if vale['Adj Close'][i] > vale['Adj Close'][i-1]: 
          OBV.append(OBV[-1] + vale['Volume'][i]) 
    elif vale['Adj Close'][i] < vale['Adj Close'][i-1]:
          OBV.append( OBV[-1] - vale['Volume'][i])
    else:
          OBV.append(OBV[-1])

# %%
vale['obv'] = OBV

# %%
vale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2620 entries, 2013-04-08 to 2023-08-31
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2620 non-null   float64
#  1   High       2620 non-null   float64
#  2   Low        2620 non-null   float64
#  3   Close      2620 non-null   float64
#  4   Adj Close  2620 non-null   float64
#  5   Volume     2620 non-null   int64
#  6   sma7       2620 non-null   float64
#  7   sma9       2620 non-null   float64
#  8   sma21      2620 non-null   float64
#  9   sma50      2620 non-null   float64
#  10  sma66      2620 non-null   float64
#  11  dist7      2620 non-null   float64
#  12  dist9      2620 non-null   float64
#  13  dist21     2620 non-null   float64
#  14  dist50     2620 non-null   float64
#  15  dist66     2620 non-null   float64
#  16  obv        2620 non-null   int64
# dtypes: float64(15), int64(2)
# memory usage: 368.4 KB

# %% [markdown]
# ##### Médias OBV

# %%
vale['sma_obv_20'] = ta.sma(vale['obv'], length=20)
vale['sma_obv_50'] = ta.sma(vale['obv'], length=50)
vale['sma_obv_100'] = ta.sma(vale['obv'], length=100)

# %%
vale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2620 entries, 2013-04-08 to 2023-08-31
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Open         2620 non-null   float64
#  1   High         2620 non-null   float64
#  2   Low          2620 non-null   float64
#  3   Close        2620 non-null   float64
#  4   Adj Close    2620 non-null   float64
#  5   Volume       2620 non-null   int64
#  6   sma7         2620 non-null   float64
#  7   sma9         2620 non-null   float64
#  8   sma21        2620 non-null   float64
#  9   sma50        2620 non-null   float64
#  10  sma66        2620 non-null   float64
#  11  dist7        2620 non-null   float64
#  12  dist9        2620 non-null   float64
#  13  dist21       2620 non-null   float64
#  14  dist50       2620 non-null   float64
#  15  dist66       2620 non-null   float64
#  16  obv          2620 non-null   int64
# ...

# %% [markdown]
# ##### RSI

# %%
vale['rsi9'] = ta.rsi(vale['Adj Close'], length=9)
vale['rsi14'] = ta.rsi(vale['Adj Close'], length=14)

# %%
vale.dropna(inplace=True)

# %%
vale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2521 entries, 2013-08-27 to 2023-08-31
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Open         2521 non-null   float64
#  1   High         2521 non-null   float64
#  2   Low          2521 non-null   float64
#  3   Close        2521 non-null   float64
#  4   Adj Close    2521 non-null   float64
#  5   Volume       2521 non-null   int64
#  6   sma7         2521 non-null   float64
#  7   sma9         2521 non-null   float64
#  8   sma21        2521 non-null   float64
#  9   sma50        2521 non-null   float64
#  10  sma66        2521 non-null   float64
#  11  dist7        2521 non-null   float64
#  12  dist9        2521 non-null   float64
#  13  dist21       2521 non-null   float64
#  14  dist50       2521 non-null   float64
#  15  dist66       2521 non-null   float64
#  16  obv          2521 non-null   int64
# ...

# %%
vale.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume      sma7  \
# Date
# 2013-08-27  14.87  15.06  14.85  14.95   8.649639  16637000  8.682701
# 2013-08-28  14.91  15.06  14.78  14.88   8.609140  16560600  8.654599
# 2013-08-29  14.80  14.85  14.40  14.47   8.371925  20391000  8.621538
# 2013-08-30  14.56  14.57  14.21  14.41   8.337212  17106800  8.620712
# 2013-09-03  14.89  15.30  14.79  15.24   8.817427  28379700  8.638895
#
#                 sma9     sma21     sma50  ...     dist9    dist21    dist50  \
# Date                                      ...
# 2013-08-27  8.749283  8.529242  8.138645  ... -0.099644  0.120398  0.510994
# 2013-08-28  8.697854  8.558721  8.145241  ... -0.088714  0.050419  0.463899
# 2013-08-29  8.639997  8.579385  8.150911  ... -0.268072 -0.207459  0.221014
# 2013-08-30  8.587926  8.599497  8.160168  ... -0.250714 -0.262285  0.177043
# 2013-09-03  8.611712  8.640548  8.178567  ...  0.205715  0.176879  0.638860
#
# ...
